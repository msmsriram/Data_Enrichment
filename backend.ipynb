# %%
import pandas as pd
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import Chroma
from langchain_community import embeddings
from langchain_community.chat_models import ChatOllama
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain.output_parsers import PydanticOutputParser
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import BSHTMLLoader
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_community.vectorstores import FAISS

# %%
model_local = ChatOllama(model="mistral",temperature=0)

# %%
# df = pd.DataFrame(columns=["unversity_name","address", "email_address", "contact_number"])

# %%
def sample(name):
    df = pd.DataFrame(columns=["university_name","address", "email_address", "contact_number"])
    if name=='LUMC':
        embedding = embeddings.OllamaEmbeddings(model='nomic-embed-text')

        vectorstore = FAISS.load_local("db_demos/test_9", embedding,allow_dangerous_deserialization=True)
        retriever = vectorstore.as_retriever()
        class format_json(BaseModel):
            university_name : str = Field(description="organization name from the given context")
            address: str = Field(description="address from the given context")
            email_address: str = Field(description="email address from the given context")
            contact_number: str = Field(description="contact number from the given context")
        after_rag_template = """Answer the question based only on the following context:
        {context} and only provide these details in this order only and the response will always will be containing these informations only such as address,contact number,email address in a json format
        {format_instructions}
        Question: {question}
        """
        parser = JsonOutputParser(pydantic_object=format_json)
        after_rag_prompt = ChatPromptTemplate.from_template(after_rag_template,partial_variables={"format_instructions": parser.get_format_instructions()},)
        after_rag_chain = (
                    {"context": retriever, "question": RunnablePassthrough()}
                    | after_rag_prompt
                    | model_local
                    | parser
                )
        json_output = after_rag_chain.invoke("provide the metioned details from the context and make sure you providing them from the given context")
        print(json_output)
        dff = pd.json_normalize(json_output)
        print(dff)
        df = pd.concat([df, dff], ignore_index=True)
        df
    elif name=='Makerere University College Of Health Sciences':
        embedding = embeddings.OllamaEmbeddings(model='nomic-embed-text')

        vectorstore = FAISS.load_local("db_demos/test_11", embedding,allow_dangerous_deserialization=True)
        retriever = vectorstore.as_retriever()
        class format_json(BaseModel):
            university_name : str = Field(description="organization name from the given context")
            address: str = Field(description="address from the given context")
            email_address: str = Field(description="email address from the given context")
            contact_number: str = Field(description="contact number from the given context")
        after_rag_template = """Answer the question based only on the following context:
        {context} and only provide these details in this order only and the response will always will be containing these informations only such as address,contact number,email address in a json format
        {format_instructions}
        Question: {question}
        """
        parser = JsonOutputParser(pydantic_object=format_json)
        after_rag_prompt = ChatPromptTemplate.from_template(after_rag_template,partial_variables={"format_instructions": parser.get_format_instructions()},)
        after_rag_chain = (
                    {"context": retriever, "question": RunnablePassthrough()}
                    | after_rag_prompt
                    | model_local
                    | parser
                )
        json_output = after_rag_chain.invoke("provide the metioned details from the context and make sure you providing them from the given context")
        print(json_output)
        dff = pd.json_normalize(json_output)
        print(dff)
        df = pd.concat([df, dff], ignore_index=True)
        df
    elif name=='University of Zimbabwe':
        embedding = embeddings.OllamaEmbeddings(model='nomic-embed-text')

        vectorstore = FAISS.load_local("db_demos/test_13", embedding,allow_dangerous_deserialization=True)
        retriever = vectorstore.as_retriever()
        class format_json(BaseModel):
            university_name : str = Field(description="organization name from the given context")
            address: str = Field(description="address from the given context")
            email_address: str = Field(description="email address from the given context")
            contact_number: str = Field(description="contact number from the given context")
        after_rag_template = """Answer the question based only on the following context:
        {context} and only provide these details in this order only and the response will always will be containing these informations only such as address,contact number,email address in a json format
        {format_instructions}
        Question: {question}
        """
        parser = JsonOutputParser(pydantic_object=format_json)
        after_rag_prompt = ChatPromptTemplate.from_template(after_rag_template,partial_variables={"format_instructions": parser.get_format_instructions()},)
        after_rag_chain = (
                    {"context": retriever, "question": RunnablePassthrough()}
                    | after_rag_prompt
                    | model_local
                    | parser
                )
        json_output = after_rag_chain.invoke("provide the metioned details from the context and make sure you providing them from the given context")
        print(json_output)
        dff = pd.json_normalize(json_output)
        print(dff)
        df = pd.concat([df, dff], ignore_index=True)
        df
    elif name=='The University of Western Australia':
        embedding = embeddings.OllamaEmbeddings(model='nomic-embed-text')

        vectorstore = FAISS.load_local("db_demos/test_6", embedding,allow_dangerous_deserialization=True)
        retriever = vectorstore.as_retriever()
        class format_json(BaseModel):
            university_name : str = Field(description="organization name from the given context")
            address: str = Field(description="address from the given context")
            email_address: str = Field(description="email address from the given context")
            contact_number: str = Field(description="contact number from the given context")
        after_rag_template = """Answer the question based only on the following context:
        {context} and only provide these details in this order only and the response will always will be containing these informations only such as address,contact number,email address in a json format
        {format_instructions}
        Question: {question}
        """
        parser = JsonOutputParser(pydantic_object=format_json)
        after_rag_prompt = ChatPromptTemplate.from_template(after_rag_template,partial_variables={"format_instructions": parser.get_format_instructions()},)
        after_rag_chain = (
                    {"context": retriever, "question": RunnablePassthrough()}
                    | after_rag_prompt
                    | model_local
                    | parser
                )
        json_output = after_rag_chain.invoke("provide the metioned details from the context and make sure you providing them from the given context")
        print(json_output)
        dff = pd.json_normalize(json_output)
        print(dff)
        df = pd.concat([df, dff], ignore_index=True)
        df
    elif name=='School of Public Health, Nanjing Medical University':
        embedding = embeddings.OllamaEmbeddings(model='nomic-embed-text')

        vectorstore = FAISS.load_local("db_demos/test_4", embedding,allow_dangerous_deserialization=True)
        retriever = vectorstore.as_retriever()
        class format_json(BaseModel):
            university_name : str = Field(description="organization name from the given context")
            address: str = Field(description="address from the given context")
            email_address: str = Field(description="email address from the given context")
            contact_number: str = Field(description="contact number from the given context")
        after_rag_template = """Answer the question based only on the following context:
        {context} and only provide these details in this order only and the response will always will be containing these informations only such as address,contact number,email address in a json format
        {format_instructions}
        Question: {question}
        """
        parser = JsonOutputParser(pydantic_object=format_json)
        after_rag_prompt = ChatPromptTemplate.from_template(after_rag_template,partial_variables={"format_instructions": parser.get_format_instructions()},)
        after_rag_chain = (
                    {"context": retriever, "question": RunnablePassthrough()}
                    | after_rag_prompt
                    | model_local
                    | parser
                )
        json_output = after_rag_chain.invoke("provide the metioned details from the context and make sure you providing them from the given context")
        print(json_output)
        dff = pd.json_normalize(json_output)
        print(dff)
        df = pd.concat([df, dff], ignore_index=True)
        df
    return dff

# %%
df_sam=sample('LUMC')
df_sam
# Out:
# {'university_name': 'Leiden University Medical Center (LUMC)', 'address': 'Weg naar Zuid 21, 2333 CC Leiden, The Netherlands', 'email_address': 'pers@lumc.nl', 'contact_number': '+31 (0)6 11 37 11 46'}
#                            university_name  \
# 0  Leiden University Medical Center (LUMC)
#
#                                              address email_address  \
# 0  Weg naar Zuid 21, 2333 CC Leiden, The Netherlands  pers@lumc.nl
#
#          contact_number
# 0  +31 (0)6 11 37 11 46
#                            university_name  \
# 0  Leiden University Medical Center (LUMC)
#
#                                              address email_address  \
# 0  Weg naar Zuid 21, 2333 CC Leiden, The Netherlands  pers@lumc.nl
#
#          contact_number
# 0  +31 (0)6 11 37 11 46

# %%
sample('Makerere University College Of Health Sciences')
# Out:
# {'university_name': 'Makerere University College Of Health Sciences', 'address': 'Office of the Principal,\n               Makerere University College of Health Sciences,\n               P.O. Box 7072,\n               Kampala, Uganda.', 'email_address': 'pr.chs[at]mak.ac.ug or the College Principal directly at principal.chs[at]mak.ac.ug', 'contact_number': '+256 41 4530 020'}
#                                   university_name  \
# 0  Makerere University College Of Health Sciences
#
#                                              address  \
# 0  Office of the Principal,\n               Maker...
#
#                                        email_address    contact_number
# 0  pr.chs[at]mak.ac.ug or the College Principal d...  +256 41 4530 020
#                                   university_name  \
# 0  Makerere University College Of Health Sciences
#
#                                              address  \
# 0  Office of the Principal,\n               Maker...
#
#                                        email_address    contact_number
# 0  pr.chs[at]mak.ac.ug or the College Principal d...  +256 41 4530 020

# %%
sample('University of Zimbabwe')
# Out:
# {'university_name': 'University of Zimbabwe', 'address': 'Mt Pleasant Road, Harare, Zimbabwe', 'email_address': 'registrar@uz.ac.zw', 'contact_number': '+263 242 303291'}
#           university_name                             address  \
# 0  University of Zimbabwe  Mt Pleasant Road, Harare, Zimbabwe
#
#         email_address   contact_number
# 0  registrar@uz.ac.zw  +263 242 303291
#           university_name                             address  \
# 0  University of Zimbabwe  Mt Pleasant Road, Harare, Zimbabwe
#
#         email_address   contact_number
# 0  registrar@uz.ac.zw  +263 242 303291
