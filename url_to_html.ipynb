# %%
from bs4 import BeautifulSoup
from selenium import webdriver

def find_and_print_links(base_url):
    driver = webdriver.Chrome()
    driver.get(base_url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    print(soup)
    # email_link = soup.find('a', href=lambda href: href and 'mailto:' in href)
    # if email_link is not None:
    #     print('Email:', email_link['href'][7:])
    # driver.quit()

base_url = 'https://www.mayoclinic.org/about-mayo-clinic/contact'
find_and_print_links(base_url)
# Out:
# <html class="hydrated" dir="ltr" lang="en"><head><script async="" id="www-widgetapi-script" src="https://www.youtube.com/s/player/e04b3b4c/www-widgetapi.vflset/www-widgetapi.js" type="text/javascript"></script><script async="" charset="utf-8" id="utag_18" src="https://resources.digital-cloud-west.medallia.com/wdcwest/160107/onsite/embed.js" type="text/javascript"></script><script async="" charset="utf-8" id="utag_17" src="//cdn5.userzoom.com/trueintent/js/uz_til_us.js?cuid=E7D5DAD86DCDE41180C90050569444FB" type="text/javascript"></script><script async="" charset="utf-8" id="utag_15" src="https://cdn.decibelinsight.net/i/14036/705830/di.js" type="text/javascript"></script><script src="https://assets.sitescdn.net/ytag/ytag.min.js"></script><style data-styles="">mc-input,mc-select,mc-dropdown,mc-modal,mc-modal-template,mc-dropdown-item,mc-modal-button-group,mc-search,mc-spinner,mc-tooltip,mc-button,mc-fieldstatus,mc-icon,mc-date-picker,mc-fieldset,mc-avatar,mc-notification,mc-badge,mc-c
# ...
