# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import Chroma
from langchain_community import embeddings
from langchain_community.embeddings import GPT4AllEmbeddings
from langchain_community.chat_models import ChatOllama
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import PromptTemplate

from langchain.output_parsers import PydanticOutputParser
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import BSHTMLLoader
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %% [markdown]
# Local LLM (Ollama - Mistral-7b)
# ---

# %%
model_local = ChatOllama(model="mistral",temperature=0)

# %%
# !pip show lxml
# Out:
# Name: lxml
# Version: 5.1.0
# Summary: Powerful and Pythonic XML processing library combining libxml2/libxslt with the ElementTree API.
# Home-page: https://lxml.de/
# Author: lxml dev team
# Author-email: lxml-dev@lxml.de
# License: BSD-3-Clause
# Location: C:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages
# Requires:
# Required-by: unstructured

# %% [markdown]
# HTML loader
# ---

# %%
loader = BSHTMLLoader("C:\\Users\\Barani\\Desktop\\local_ollama\\html\\cancer_gov_pages.html",open_encoding='utf-8')
data = loader.load()
# print(data)

# %%
len(data)
# Out:
# 1

# %% [markdown]
# Spliting into chunks
# ---

# %%
text_splitter = CharacterTextSplitter.from_tiktoken_encoder(chunk_size=7500, chunk_overlap=200)
doc_splits = text_splitter.split_documents(data)
# len(doc_splits)
# Out:
# Created a chunk of size 16803, which is longer than the specified 7500
# Created a chunk of size 10873, which is longer than the specified 7500
# Created a chunk of size 25747, which is longer than the specified 7500
# Created a chunk of size 62502, which is longer than the specified 7500
# Created a chunk of size 18729, which is longer than the specified 7500
# Created a chunk of size 86418, which is longer than the specified 7500
# Created a chunk of size 62897, which is longer than the specified 7500
# Created a chunk of size 31533, which is longer than the specified 7500
# Created a chunk of size 13323, which is longer than the specified 7500
# Created a chunk of size 8938, which is longer than the specified 7500
# Created a chunk of size 75041, which is longer than the specified 7500
# Created a chunk of size 75750, which is longer than the specified 7500
# Created a chunk of size 8034, which is longer than the specified 7500
# Created a chunk of size 7835, which is longer than the specified 7500
# Created a chunk of size 8340, which is longer than the specified 7500
# Created a chunk of size 15937, which is longer than the specified 7500
# Created a chunk of size 14430, which is longer than the specified 7500
# Created a chunk of size 26442, which is longer than the specified 7500
# Created a chunk of size 11243, which is longer than the specified 7500
# Created a chunk of size 12062, which is longer than the specified 7500
# Created a chunk of size 9051, which is longer than the specified 7500
# Created a chunk of size 27272, which is longer than the specified 7500
# Created a chunk of size 8134, which is longer than the specified 7500
# Created a chunk of size 10729, which is longer than the specified 7500
# Created a chunk of size 12510, which is longer than the specified 7500
# Created a chunk of size 7921, which is longer than the specified 7500
# Created a chunk of size 47576, which is longer than the specified 7500
# Created a chunk of size 44292, which is longer than the specified 7500
# Created a chunk of size 17325, which is longer than the specified 7500
# Created a chunk of size 8420, which is longer than the specified 7500
# Created a chunk of size 8533, which is longer than the specified 7500
# Created a chunk of size 19833, which is longer than the specified 7500
# Created a chunk of size 10077, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7798, which is longer than the specified 7500
# Created a chunk of size 12311, which is longer than the specified 7500
# Created a chunk of size 9357, which is longer than the specified 7500
# Created a chunk of size 7594, which is longer than the specified 7500
# Created a chunk of size 9191, which is longer than the specified 7500
# Created a chunk of size 8998, which is longer than the specified 7500
# Created a chunk of size 9201, which is longer than the specified 7500
# Created a chunk of size 9551, which is longer than the specified 7500
# Created a chunk of size 7873, which is longer than the specified 7500
# Created a chunk of size 8347, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 8478, which is longer than the specified 7500
# Created a chunk of size 13909, which is longer than the specified 7500
# Created a chunk of size 14635, which is longer than the specified 7500
# Created a chunk of size 20160, which is longer than the specified 7500
# Created a chunk of size 43874, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7643, which is longer than the specified 7500
# Created a chunk of size 9480, which is longer than the specified 7500
# Created a chunk of size 13395, which is longer than the specified 7500
# Created a chunk of size 14261, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 12716, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# ...
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 10181, which is longer than the specified 7500
# Created a chunk of size 11072, which is longer than the specified 7500
# Created a chunk of size 7717, which is longer than the specified 7500
# Created a chunk of size 8871, which is longer than the specified 7500
# Created a chunk of size 10266, which is longer than the specified 7500
# Created a chunk of size 34759, which is longer than the specified 7500
# Created a chunk of size 10957, which is longer than the specified 7500
# Created a chunk of size 12716, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 12716, which is longer than the specified 7500
# Created a chunk of size 13283, which is longer than the specified 7500
# Created a chunk of size 13343, which is longer than the specified 7500
# Created a chunk of size 14432, which is longer than the specified 7500
# Created a chunk of size 10181, which is longer than the specified 7500
# Created a chunk of size 11072, which is longer than the specified 7500
# Created a chunk of size 7717, which is longer than the specified 7500
# Created a chunk of size 8871, which is longer than the specified 7500
# Created a chunk of size 10266, which is longer than the specified 7500
# Created a chunk of size 15169, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 16856, which is longer than the specified 7500
# Created a chunk of size 8894, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 10116, which is longer than the specified 7500
# Created a chunk of size 11113, which is longer than the specified 7500
# Created a chunk of size 13546, which is longer than the specified 7500
# Created a chunk of size 10666, which is longer than the specified 7500
# Created a chunk of size 26800, which is longer than the specified 7500
# Created a chunk of size 67901, which is longer than the specified 7500
# Created a chunk of size 37504, which is longer than the specified 7500
# Created a chunk of size 7828, which is longer than the specified 7500
# Created a chunk of size 35059, which is longer than the specified 7500
# Created a chunk of size 9191, which is longer than the specified 7500
# Created a chunk of size 10181, which is longer than the specified 7500
# Created a chunk of size 11072, which is longer than the specified 7500
# Created a chunk of size 7717, which is longer than the specified 7500
# Created a chunk of size 8871, which is longer than the specified 7500
# Created a chunk of size 10266, which is longer than the specified 7500
# Created a chunk of size 14432, which is longer than the specified 7500
# Created a chunk of size 7751, which is longer than the specified 7500
# Created a chunk of size 16019, which is longer than the specified 7500
# Created a chunk of size 37269, which is longer than the specified 7500
# Created a chunk of size 14966, which is longer than the specified 7500
# Created a chunk of size 8651, which is longer than the specified 7500
# Created a chunk of size 13058, which is longer than the specified 7500
# Created a chunk of size 11312, which is longer than the specified 7500
# Created a chunk of size 9843, which is longer than the specified 7500
# Created a chunk of size 8242, which is longer than the specified 7500
# Created a chunk of size 22755, which is longer than the specified 7500
# Created a chunk of size 10409, which is longer than the specified 7500
# Created a chunk of size 21377, which is longer than the specified 7500
# Created a chunk of size 13813, which is longer than the specified 7500
# Created a chunk of size 12451, which is longer than the specified 7500
# Created a chunk of size 10133, which is longer than the specified 7500
# Created a chunk of size 9260, which is longer than the specified 7500
# Created a chunk of size 25185, which is longer than the specified 7500
# Created a chunk of size 7862, which is longer than the specified 7500
# Created a chunk of size 18980, which is longer than the specified 7500
# Created a chunk of size 16774, which is longer than the specified 7500
# Created a chunk of size 9871, which is longer than the specified 7500
# Created a chunk of size 15900, which is longer than the specified 7500
# Created a chunk of size 13862, which is longer than the specified 7500
# Created a chunk of size 16409, which is longer than the specified 7500
# Created a chunk of size 15601, which is longer than the specified 7500
# Created a chunk of size 22544, which is longer than the specified 7500
# Created a chunk of size 12042, which is longer than the specified 7500
# Created a chunk of size 12084, which is longer than the specified 7500
# Created a chunk of size 12919, which is longer than the specified 7500
# Created a chunk of size 23263, which is longer than the specified 7500
# Created a chunk of size 13075, which is longer than the specified 7500
# Created a chunk of size 8503, which is longer than the specified 7500
# Created a chunk of size 9436, which is longer than the specified 7500
# Created a chunk of size 13465, which is longer than the specified 7500
# Created a chunk of size 8398, which is longer than the specified 7500
# Created a chunk of size 15247, which is longer than the specified 7500
# Created a chunk of size 13254, which is longer than the specified 7500
# Created a chunk of size 9687, which is longer than the specified 7500
# Created a chunk of size 28044, which is longer than the specified 7500
# Created a chunk of size 16663, which is longer than the specified 7500
# Created a chunk of size 8386, which is longer than the specified 7500
# Created a chunk of size 28787, which is longer than the specified 7500
# Created a chunk of size 12157, which is longer than the specified 7500
# Created a chunk of size 26921, which is longer than the specified 7500
# Created a chunk of size 12571, which is longer than the specified 7500
# Created a chunk of size 13614, which is longer than the specified 7500
# Created a chunk of size 7764, which is longer than the specified 7500
# Created a chunk of size 7594, which is longer than the specified 7500
# Created a chunk of size 16005, which is longer than the specified 7500
# Created a chunk of size 22599, which is longer than the specified 7500
# Created a chunk of size 15040, which is longer than the specified 7500
# Created a chunk of size 12118, which is longer than the specified 7500
# Created a chunk of size 13183, which is longer than the specified 7500
# Created a chunk of size 17424, which is longer than the specified 7500
# Created a chunk of size 20225, which is longer than the specified 7500
# Created a chunk of size 24075, which is longer than the specified 7500
# Created a chunk of size 15475, which is longer than the specified 7500
# Created a chunk of size 19973, which is longer than the specified 7500
# Created a chunk of size 9065, which is longer than the specified 7500
# Created a chunk of size 27917, which is longer than the specified 7500
# Created a chunk of size 11689, which is longer than the specified 7500
# Created a chunk of size 12164, which is longer than the specified 7500
# Created a chunk of size 10220, which is longer than the specified 7500
# Created a chunk of size 26413, which is longer than the specified 7500
# Created a chunk of size 12597, which is longer than the specified 7500
# Created a chunk of size 12889, which is longer than the specified 7500
# Created a chunk of size 26741, which is longer than the specified 7500
# Created a chunk of size 22373, which is longer than the specified 7500
# Created a chunk of size 12294, which is longer than the specified 7500
# Created a chunk of size 11162, which is longer than the specified 7500
# Created a chunk of size 13591, which is longer than the specified 7500
# Created a chunk of size 13551, which is longer than the specified 7500
# Created a chunk of size 16467, which is longer than the specified 7500
# Created a chunk of size 11068, which is longer than the specified 7500
# Created a chunk of size 15877, which is longer than the specified 7500
# Created a chunk of size 21990, which is longer than the specified 7500
# Created a chunk of size 7672, which is longer than the specified 7500
# Created a chunk of size 13896, which is longer than the specified 7500
# Created a chunk of size 10427, which is longer than the specified 7500
# Created a chunk of size 8914, which is longer than the specified 7500
# Created a chunk of size 11932, which is longer than the specified 7500
# Created a chunk of size 11554, which is longer than the specified 7500
# Created a chunk of size 12730, which is longer than the specified 7500
# Created a chunk of size 7665, which is longer than the specified 7500
# Created a chunk of size 23100, which is longer than the specified 7500
# Created a chunk of size 28568, which is longer than the specified 7500
# Created a chunk of size 13289, which is longer than the specified 7500
# Created a chunk of size 9444, which is longer than the specified 7500
# Created a chunk of size 9838, which is longer than the specified 7500
# Created a chunk of size 11365, which is longer than the specified 7500
# Created a chunk of size 11550, which is longer than the specified 7500
# Created a chunk of size 19623, which is longer than the specified 7500
# Created a chunk of size 10077, which is longer than the specified 7500
# Created a chunk of size 34759, which is longer than the specified 7500
# Created a chunk of size 10957, which is longer than the specified 7500
# Created a chunk of size 14447, which is longer than the specified 7500
# Created a chunk of size 20970, which is longer than the specified 7500
# Created a chunk of size 26517, which is longer than the specified 7500
# Created a chunk of size 10774, which is longer than the specified 7500
# Created a chunk of size 13823, which is longer than the specified 7500
# Created a chunk of size 12855, which is longer than the specified 7500
# Created a chunk of size 14206, which is longer than the specified 7500
# Created a chunk of size 9686, which is longer than the specified 7500
# Created a chunk of size 30508, which is longer than the specified 7500
# Created a chunk of size 17038, which is longer than the specified 7500
# Created a chunk of size 16467, which is longer than the specified 7500
# Created a chunk of size 32880, which is longer than the specified 7500
# Created a chunk of size 9698, which is longer than the specified 7500
# Created a chunk of size 8292, which is longer than the specified 7500
# Created a chunk of size 16342, which is longer than the specified 7500
# Created a chunk of size 16984, which is longer than the specified 7500
# Created a chunk of size 13556, which is longer than the specified 7500
# Created a chunk of size 46273, which is longer than the specified 7500
# Created a chunk of size 13212, which is longer than the specified 7500
# Created a chunk of size 30833, which is longer than the specified 7500
# Created a chunk of size 16277, which is longer than the specified 7500
# Created a chunk of size 13788, which is longer than the specified 7500
# Created a chunk of size 19359, which is longer than the specified 7500
# Created a chunk of size 19360, which is longer than the specified 7500
# Created a chunk of size 8125, which is longer than the specified 7500
# Created a chunk of size 30791, which is longer than the specified 7500
# Created a chunk of size 10219, which is longer than the specified 7500
# Created a chunk of size 22499, which is longer than the specified 7500
# Created a chunk of size 16852, which is longer than the specified 7500
# Created a chunk of size 99247, which is longer than the specified 7500
# Created a chunk of size 15368, which is longer than the specified 7500
# Created a chunk of size 18650, which is longer than the specified 7500
# Created a chunk of size 37095, which is longer than the specified 7500
# Created a chunk of size 20490, which is longer than the specified 7500
# Created a chunk of size 15292, which is longer than the specified 7500
# Created a chunk of size 23227, which is longer than the specified 7500
# Created a chunk of size 12883, which is longer than the specified 7500
# Created a chunk of size 32133, which is longer than the specified 7500
# Created a chunk of size 19044, which is longer than the specified 7500
# Created a chunk of size 41355, which is longer than the specified 7500
# Created a chunk of size 10828, which is longer than the specified 7500
# Created a chunk of size 13820, which is longer than the specified 7500
# Created a chunk of size 11145, which is longer than the specified 7500
# Created a chunk of size 29570, which is longer than the specified 7500
# Created a chunk of size 14842, which is longer than the specified 7500
# Created a chunk of size 12034, which is longer than the specified 7500
# Created a chunk of size 11679, which is longer than the specified 7500
# Created a chunk of size 33552, which is longer than the specified 7500
# Created a chunk of size 30190, which is longer than the specified 7500
# Created a chunk of size 7920, which is longer than the specified 7500
# Created a chunk of size 8293, which is longer than the specified 7500
# Created a chunk of size 11952, which is longer than the specified 7500
# Created a chunk of size 12079, which is longer than the specified 7500
# Created a chunk of size 27111, which is longer than the specified 7500
# Created a chunk of size 10144, which is longer than the specified 7500
# Created a chunk of size 7636, which is longer than the specified 7500
# Created a chunk of size 30964, which is longer than the specified 7500
# Created a chunk of size 36703, which is longer than the specified 7500
# Created a chunk of size 12647, which is longer than the specified 7500
# Created a chunk of size 27094, which is longer than the specified 7500
# Created a chunk of size 41670, which is longer than the specified 7500
# Created a chunk of size 24021, which is longer than the specified 7500
# Created a chunk of size 20499, which is longer than the specified 7500
# Created a chunk of size 13203, which is longer than the specified 7500
# Created a chunk of size 11843, which is longer than the specified 7500
# Created a chunk of size 13913, which is longer than the specified 7500
# Created a chunk of size 18863, which is longer than the specified 7500
# Created a chunk of size 19388, which is longer than the specified 7500
# Created a chunk of size 10655, which is longer than the specified 7500
# Created a chunk of size 23409, which is longer than the specified 7500
# Created a chunk of size 23322, which is longer than the specified 7500
# Created a chunk of size 11500, which is longer than the specified 7500
# Created a chunk of size 10447, which is longer than the specified 7500
# Created a chunk of size 15216, which is longer than the specified 7500
# Created a chunk of size 10658, which is longer than the specified 7500
# Created a chunk of size 10424, which is longer than the specified 7500
# Created a chunk of size 9454, which is longer than the specified 7500
# Created a chunk of size 22681, which is longer than the specified 7500

# %%
len(doc_splits)
# Out:
# 5736

# %% [markdown]
# Converting into embeddings and store into ChromaDB
# ---

# %% [markdown]
# Save to disk

# %%
# vectorstore = Chroma.from_documents(
#             documents=doc_splits,
#             collection_name="rag-chroma",
#             embedding=embeddings.ollama.OllamaEmbeddings(model='nomic-embed-text'),
#             persist_directory="./chroma"
#         )
# vectorstore.persist()
# retriever = vectorstore.as_retriever()

# %% [markdown]
# Load from disk

# %%
embedding_function=embeddings.ollama.OllamaEmbeddings(model='nomic-embed-text'),

# %%
vectorstore = Chroma(persist_directory="C:\\Users\\Barani\\Desktop\\local_ollama\\chroma",embedding_function=embedding_function)
# retriever = vectorstore.as_retriever()

# %%
query="what is cancer"

# %%
# docs = vectorstore.similarity_search(query)

# %%
print(vectorstore._collection.count())
# Out:
# 0

# %%
type(retriever)
# Out:
# langchain_core.vectorstores.VectorStoreRetriever

# %%
print(dir(retriever))
# Out:
# ['Config', 'InputType', 'OutputType', '__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__config__', '__custom_root_type__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__exclude_fields__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_validators__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__include_fields__', '__init__', '__init_subclass__', '__iter__', '__json_encoder__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__or__', '__orig_bases__', '__parameters__', '__post_root_validators__', '__pre_root_validators__', '__pretty__', '__private_attributes__', '__reduce__', '__reduce_ex__', '__repr__', '__repr_args__', '__repr_name__', '__repr_str__', '__rich_repr__', '__ror__', '__schema_cache__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__try_update_forward_refs__', '__validators__', '__weakref__', '_abatch_with_config', '_abc_impl', '_acall_with_config', '_aget_relevant_documents', '_atransform_stream_with_config', '_batch_with_config', '_calculate_keys', '_call_with_config', '_copy_and_set_values', '_decompose_class', '_enforce_dict_if_root', '_expects_other_args', '_get_relevant_documents', '_get_value', '_init_private_attributes', '_is_protocol', '_iter', '_lc_kwargs', '_new_arg_supported', '_transform_stream_with_config', 'aadd_documents', 'abatch', 'abatch_as_completed', 'add_documents', 'aget_relevant_documents', 'ainvoke', 'allowed_search_types', 'assign', 'astream', 'astream_events', 'astream_log', 'atransform', 'batch', 'batch_as_completed', 'bind', 'config_schema', 'config_specs', 'configurable_alternatives', 'configurable_fields', 'construct', 'copy', 'dict', 'from_orm', 'get_graph', 'get_input_schema', 'get_lc_namespace', 'get_name', 'get_output_schema', 'get_prompts', 'get_relevant_documents', 'input_schema', 'invoke', 'is_lc_serializable', 'json', 'lc_attributes', 'lc_id', 'lc_secrets', 'map', 'metadata', 'name', 'output_schema', 'parse_file', 'parse_obj', 'parse_raw', 'pick', 'pipe', 'schema', 'schema_json', 'search_kwargs', 'search_type', 'stream', 'tags', 'to_json', 'to_json_not_implemented', 'transform', 'update_forward_refs', 'validate', 'validate_search_type', 'vectorstore', 'with_config', 'with_fallbacks', 'with_listeners', 'with_retry', 'with_types']

# %%
# import chromadb
# persistent_client = chromadb.PersistentClient()
# collection = persistent_client.get_or_create_collection("rag-chroma")
# langchain_chroma = Chroma(
#     client=persistent_client,
#     collection_name="rag-chroma",
#     embedding_function=embedding_function,
# )
# retriever = langchain_chroma.as_retriever()

# %% [markdown]
# Before RAG
# ---

# %%
# 3. Before RAG
print("Before RAG\n")
before_rag_template = "{topic}"
before_rag_prompt = ChatPromptTemplate.from_template(before_rag_template)
before_rag_chain = before_rag_prompt | model_local | StrOutputParser()

# %%
print(before_rag_chain.invoke({"topic": "provide me the General number of mayo clinic which is in Arizona?"}))

# %% [markdown]
# After RAG
# ---

# %%
# 4. After RAG
print("\n########\nAfter RAG\n")
# after_rag_template = """provide the answer for the question only from this given context:
# {context}
# Question: {question} and only give the answer from the given context
# """
after_rag_template = """Given the context:
{context}

Question: {question}

Please provide all instances of the answer from the given context. If there are multiple instances, list them all.
"""
after_rag_prompt = ChatPromptTemplate.from_template(after_rag_template)
after_rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | after_rag_prompt
    | model_local
    | StrOutputParser()
)
# Out:
# ########
# After RAG

# %%
chunks = []
async for chunk in after_rag_chain.astream("what are the informations are you able to see in the given context and tell in a brief manner?"):
    chunks.append(chunk)
    print(chunk, end="", flush=True)
# Out:
#  The given context is a section of a webpage from the National Cancer Institute (NCI) website about childhood mesothelioma. Here are some key points and pieces of information that can be extracted from it:
#
# * Malignant mesothelioma is a type of cancer where malignant cells form in the thin layer of tissue called the mesothelium, which covers various organs such as the lungs, heart, and abdominal cavity.
# * Symptoms of childhood mesothelioma may include chest pain, shortness of breath, coughing, and fluid buildup in the chest or abdomen.
# * Diagnosis of childhood mesothelioma involves imaging tests such as X-rays, CT scans, MRI scans, and PET scans, as well as biopsies to confirm the presence of cancer cells.
# * Treatment options for childhood mesothelioma include surgery, chemotherapy, radiation therapy, and a combination of these approaches.
# * Prognosis (chance of recovery) depends on various factors such as whether the cancer has spread throughout the thin layer of tissue or into organs, and whether it is newly diagnosed or has recurred (come back).
# * The NCI website provides comprehensive information about childhood mesothelioma, including its causes, symptoms, diagnosis, treatment, and prognosis. It also includes links to clinical trials and resources for patients and their families.

# %%
chunks = []
async for chunk in after_rag_chain.astream("what are the informations are you able to see in the given context and tell in a brief manner?"):
    chunks.append(chunk)
    print(chunk, end="", flush=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 2
#       1 chunks = []
# ----> 2 async for chunk in after_rag_chain.astream("what are the informations are you able to see in the given context and tell in a brief manner?"):
#       3     chunks.append(chunk)
#       4     print(chunk, end="", flush=True)
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:2710, in RunnableSequence.astream(self, input, config, **kwargs)
#    2707 async def input_aiter() -> AsyncIterator[Input]:
#    2708     yield input
# -> 2710 async for chunk in self.atransform(input_aiter(), config, **kwargs):
#    2711     yield chunk
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:2693, in RunnableSequence.atransform(self, input, config, **kwargs)
#    2687 async def atransform(
#    2688     self,
#    2689     input: AsyncIterator[Input],
#    2690     config: Optional[RunnableConfig] = None,
#    2691     **kwargs: Optional[Any],
#    2692 ) -> AsyncIterator[Output]:
# -> 2693     async for chunk in self._atransform_stream_with_config(
#    2694         input,
#    2695         self._atransform,
#    2696         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    2697         **kwargs,
#    2698     ):
#    2699         yield chunk
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:1842, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1840 while True:
#    1841     if accepts_context(asyncio.create_task):
# -> 1842         chunk: Output = await asyncio.create_task(  # type: ignore[call-arg]
#    1843             py_anext(iterator),  # type: ignore[arg-type]
#    1844             context=context,
#    1845         )
#    1846     else:
#    1847         chunk = cast(Output, await py_anext(iterator))
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:2663, in RunnableSequence._atransform(self, input, run_manager, config)
#    2655 for step in steps:
#    2656     final_pipeline = step.atransform(
#    2657         final_pipeline,
#    2658         patch_config(
#    (...)
#    2661         ),
#    2662     )
# -> 2663 async for output in final_pipeline:
#    2664     yield output
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\output_parsers\transform.py:60, in BaseTransformOutputParser.atransform(self, input, config, **kwargs)
#      54 async def atransform(
#      55     self,
#      56     input: AsyncIterator[Union[str, BaseMessage]],
#      57     config: Optional[RunnableConfig] = None,
#      58     **kwargs: Any,
#      59 ) -> AsyncIterator[T]:
# ---> 60     async for chunk in self._atransform_stream_with_config(
#      61         input, self._atransform, config, run_type="parser"
#      62     ):
#      63         yield chunk
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:1806, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1804 input_for_tracing, input_for_transform = atee(input, 2)
#    1805 # Start the input iterator to ensure the input runnable starts before this one
# -> 1806 final_input: Optional[Input] = await py_anext(input_for_tracing, None)
#    1807 final_input_supported = True
#    1808 final_output: Optional[Output] = None
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\utils\aiter.py:62, in py_anext.<locals>.anext_impl()
#      55 async def anext_impl() -> Union[T, Any]:
#      56     try:
#      57         # The C code is way more low-level than this, as it implements
#      58         # all methods of the iterator protocol. In this implementation
#      59         # we're relying on higher-level coroutine concepts, but that's
#      60         # exactly what we want -- crosstest pure-Python high-level
#      61         # implementation and low-level C anext() iterators.
# ---> 62         return await __anext__(iterator)
#      63     except StopAsyncIteration:
#      64         return default
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\utils\aiter.py:97, in tee_peer(iterator, buffer, peers, lock)
#      95     continue
#      96 try:
# ---> 97     item = await iterator.__anext__()
#      98 except StopAsyncIteration:
#      99     break
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:1242, in Runnable.atransform(self, input, config, **kwargs)
#    1239 final: Input
#    1240 got_first_val = False
# -> 1242 async for chunk in input:
#    1243     if not got_first_val:
#    1244         final = adapt_first_streaming_chunk(chunk)  # type: ignore
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:1242, in Runnable.atransform(self, input, config, **kwargs)
#    1239 final: Input
#    1240 got_first_val = False
# -> 1242 async for chunk in input:
#    1243     if not got_first_val:
#    1244         final = adapt_first_streaming_chunk(chunk)  # type: ignore
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:3127, in RunnableParallel.atransform(self, input, config, **kwargs)
#    3121 async def atransform(
#    3122     self,
#    3123     input: AsyncIterator[Input],
#    3124     config: Optional[RunnableConfig] = None,
#    3125     **kwargs: Any,
#    3126 ) -> AsyncIterator[Dict[str, Any]]:
# -> 3127     async for chunk in self._atransform_stream_with_config(
#    3128         input, self._atransform, config, **kwargs
#    3129     ):
#    3130         yield chunk
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:1842, in Runnable._atransform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1840 while True:
#    1841     if accepts_context(asyncio.create_task):
# -> 1842         chunk: Output = await asyncio.create_task(  # type: ignore[call-arg]
#    1843             py_anext(iterator),  # type: ignore[arg-type]
#    1844             context=context,
#    1845         )
#    1846     else:
#    1847         chunk = cast(Output, await py_anext(iterator))
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:3114, in RunnableParallel._atransform(self, input, run_manager, config)
#    3112 (step_name, generator) = tasks.pop(task)
#    3113 try:
# -> 3114     chunk = AddableDict({step_name: task.result()})
#    3115     yield chunk
#    3116     new_task = asyncio.create_task(get_next_chunk(generator))
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:3097, in RunnableParallel._atransform.<locals>.get_next_chunk(generator)
#    3096 async def get_next_chunk(generator: AsyncIterator) -> Optional[Output]:
# -> 3097     return await py_anext(generator)
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:1259, in Runnable.atransform(self, input, config, **kwargs)
#    1252             raise TypeError(
#    1253                 f"Failed while trying to add together "
#    1254                 f"type {type(final)} and {type(chunk)}."
#    1255                 f"These types should be addable for atransform to work."
#    1256             )
#    1258 if got_first_val:
# -> 1259     async for output in self.astream(final, config, **kwargs):
#    1260         yield output
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\base.py:746, in Runnable.astream(self, input, config, **kwargs)
#     736 async def astream(
#     737     self,
#     738     input: Input,
#     739     config: Optional[RunnableConfig] = None,
#     740     **kwargs: Optional[Any],
#     741 ) -> AsyncIterator[Output]:
#     742     """
#     743     Default implementation of astream, which calls ainvoke.
#     744     Subclasses should override this method if they support streaming output.
#     745     """
# --> 746     yield await self.ainvoke(input, config, **kwargs)
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\retrievers.py:157, in BaseRetriever.ainvoke(self, input, config, **kwargs)
#     150 async def ainvoke(
#     151     self,
#     152     input: str,
#     153     config: Optional[RunnableConfig] = None,
#     154     **kwargs: Any,
#     155 ) -> List[Document]:
#     156     config = ensure_config(config)
# --> 157     return await self.aget_relevant_documents(
#     158         input,
#     159         callbacks=config.get("callbacks"),
#     160         tags=config.get("tags"),
#     161         metadata=config.get("metadata"),
#     162         run_name=config.get("run_name"),
#     163         **kwargs,
#     164     )
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\retrievers.py:302, in BaseRetriever.aget_relevant_documents(self, query, callbacks, tags, metadata, run_name, **kwargs)
#     300 except Exception as e:
#     301     await run_manager.on_retriever_error(e)
# --> 302     raise e
#     303 else:
#     304     await run_manager.on_retriever_end(
#     305         result,
#     306     )
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\retrievers.py:295, in BaseRetriever.aget_relevant_documents(self, query, callbacks, tags, metadata, run_name, **kwargs)
#     293 _kwargs = kwargs if self._expects_other_args else {}
#     294 if self._new_arg_supported:
# --> 295     result = await self._aget_relevant_documents(
#     296         query, run_manager=run_manager, **_kwargs
#     297     )
#     298 else:
#     299     result = await self._aget_relevant_documents(query, **_kwargs)
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\vectorstores.py:694, in VectorStoreRetriever._aget_relevant_documents(self, query, run_manager)
#     690 async def _aget_relevant_documents(
#     691     self, query: str, *, run_manager: AsyncCallbackManagerForRetrieverRun
#     692 ) -> List[Document]:
#     693     if self.search_type == "similarity":
# --> 694         docs = await self.vectorstore.asimilarity_search(
#     695             query, **self.search_kwargs
#     696         )
#     697     elif self.search_type == "similarity_score_threshold":
#     698         docs_and_similarities = (
#     699             await self.vectorstore.asimilarity_search_with_relevance_scores(
#     700                 query, **self.search_kwargs
#     701             )
#     702         )
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\vectorstores.py:404, in VectorStore.asimilarity_search(self, query, k, **kwargs)
#     399 """Return docs most similar to query."""
#     401 # This is a temporary workaround to make the similarity search
#     402 # asynchronous. The proper solution is to make the similarity search
#     403 # asynchronous in the vector store implementations.
# --> 404 return await run_in_executor(None, self.similarity_search, query, k=k, **kwargs)
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_core\runnables\config.py:514, in run_in_executor(executor_or_config, func, *args, **kwargs)
#     501 """Run a function in an executor.
#     502
#     503 Args:
#    (...)
#     510     Output: The output of the function.
#     511 """
#     512 if executor_or_config is None or isinstance(executor_or_config, dict):
#     513     # Use default executor with context copied from current context
# --> 514     return await asyncio.get_running_loop().run_in_executor(
#     515         None,
#     516         cast(Callable[..., T], partial(copy_context().run, func, *args, **kwargs)),
#     517     )
#     519 return await asyncio.get_running_loop().run_in_executor(
#     520     executor_or_config, partial(func, **kwargs), *args
#     521 )
#
# File ~\miniconda3\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_community\vectorstores\chroma.py:348, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     331 def similarity_search(
#     332     self,
#     333     query: str,
#    (...)
#     336     **kwargs: Any,
#     337 ) -> List[Document]:
#     338     """Run similarity search with Chroma.
#     339
#     340     Args:
#    (...)
#     346         List[Document]: List of documents most similar to the query text.
#     347     """
# --> 348     docs_and_scores = self.similarity_search_with_score(
#     349         query, k, filter=filter, **kwargs
#     350     )
#     351     return [doc for doc, _ in docs_and_scores]
#
# File c:\Users\Barani\Desktop\local_ollama\ollama_2\Lib\site-packages\langchain_community\vectorstores\chroma.py:437, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     429     results = self.__query_collection(
#     430         query_texts=[query],
#     431         n_results=k,
#    (...)
#     434         **kwargs,
#     435     )
#     436 else:
# --> 437     query_embedding = self._embedding_function.embed_query(query)
#     438     results = self.__query_collection(
#     439         query_embeddings=[query_embedding],
#     440         n_results=k,
#    (...)
#     443         **kwargs,
#     444     )
#     446 return _results_to_docs_and_scores(results)
#
# AttributeError: 'tuple' object has no attribute 'embed_query'
